# %% [markdown]
# Dataset WINEREVIEWS di kaggle

# %%
import pandas as pd

# %%
#membuat dataframe
fruits = pd.DataFrame({'Apples': [30], 'Bananas': [10]})
#fruits

fruit_sales = pd.DataFrame({'Apples': [36,21], 'Bananas': [20,33]}, index=['2022 Sales', '2023 Sales'])
#fruit_sales
# Out:
#             Apples  Bananas
# 2022 Sales      36       20
# 2023 Sales      21       33

# %%
#membuat series
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'], name='DInner')
ingredients
#series hanya punya 1 kolom dan 1 nama
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# dtype: object

# %%
#membaca dataset
df = pd.read_csv('urlKeDataset', index_col=0)
#indexcol dipakai jika dalam data set ada kolom untuk index (sudah dibuat di datasetnya)

# %%
#save dataframe
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals

animals.to_csv('data_animals')

# %%
#pilih column
#dataframe.column_name
#animals.Cows
#animals['Cows']

#pilih value pertama dari column
#animals.Cows[0]

#pilih row
#row_pertama = animals.iloc[0]
#row_pertama

#pilih N value pertama dari column
#first_cows = animals.Cows.iloc[:2]
#first_cows

#pilih beberapa row berdasarkan index label
#sample_df = animals.iloc[[0,1]] #[[2,8,13]] contoh lain
#sample_df

#buat dataframe baru berdasarkan index label dan column tertentu
#df = reviews.loc[[0,10,100,1000], ['country', 'province', 'region_1', 'region_2']]

#buat df baru berdasarkan column country dan variety yang 100 pertama muncul
#df = reviews.loc[[:99] ,['country', 'variety']] #99 karena loc returnnya tambah 1

#conditional selection
#pilih semua dari dataframe yang negaranya italy
#italian_wines = reviews[reviews.country == 'Italy']

#buat df berisi wines dari australia dan new zealand yang memiliki points 95 keatas
#top_oceania_wines = reviews[(reviews.points >= 95) & ((reviews.country == 'Australia') | (reviews.country == 'New Zealand#'))]
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. loc, meanwhile, indexes inclusively.
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.iloc[0:999].

# %%
#mencari median
#reviews.points.median()

#menampilkan semua negara tanpa adanya duplikat
#reviews.country.unique()

#berapa kali setiap negara muncul di dataset
#reviews_per_country = reviews.country.values_count()

#mengurangi harga setiap row dengan mean
#centered_price = reviews.price.map(lambda p: p - reviews.price.mean())

#wine mana yang memiliki rasio point ke price yang paling tinggi
import numpy as np
#bargain_idx = (reviews.points/reviews.price).idxmax()
#bargain_wine = reviews.loc[bargain_idx, 'title']

#buat series dimana isinya reviews yang deskripsinya ada kata tropical dan fruity
#tropical_count = reviews.description.map(lambda d: 'tropical' in d).sum() #sum untuk menjumlah berapa kali deskripsi yang ada tropical muncul
#fuity_count = reviews.description.map(lambda d: 'fruity' in d).sum()
#descriptor_count = pd.Series([tropical_count, fruity_count], index=['tropical', 'fruity'])

'''def check_stars(row):
  poin = row.points
  if(row.country == 'Canada'):
    return 3
  elif poin >= 95:
    return 3
  elif poin >= 85:
    return 2
  else:
    return 1'''

#star_ratings = reviews.apply(check_stars, axis='columns') #axis = yang dicek kolomnya

# %%
#group by
#berapa banyak review yang dimiliki setiap reviewer
#reviews_written = reviews.groupby(['taster_twitter_handle'])['taster_twitter_handle'].count()

#rating terbaik setiap harga yang dimiliki wine
#best_rating_per_price = reviews.groupby('price')['points'].max().sort_index()

#harga minimum dan maximum setiap variasi wine
#price_extremes = reviews.groupby('variety').price.agg([min, max])

#variasi wine paling mahal
#sorted_varieties = price_extremes.sort_values(by=['min', 'max'], ascending=False)

#rata rata review setiap reviewer
#reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()

#kombinasi wine dan variasi paling banyak
#country_variety_counts = reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)

# %%
#nunjukin tipe data dari points
#dtype = reviews.points.dtype

#buat series dari points yang diubah ke string
#points_string = reviews.points.astype('str')

#berapa banyak reviews yang harganya kosong
#missing_prices_reviews = reviews[pd.isnull(reviews.price)]
#n_missing_prices = len(missing_prices_reviews)

#bikin series menghitung jumlah setiap value muncul di region_1, ganti data hilang dengan unknown
#ganti_null = reviews.region_1.fillna("Unknown")
#reviews_per_region = ganti_null.value_counts().sort_values(ascending=False)

# %%
#ganti nama kolom region_1 dan region_2
#renamed = reviews.rename(columns={'region_1': 'region', 'region_2': 'locale'})

#gabungin 2 dataframe
'''gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
movie_products['subreddit'] = "r/movies"'''
#combined_products = pd.concat([gaming_products, movie_products])

#gabungin 2 tabel yang punya referensi MeetID
'''powerlifting_meets = pd.read_csv("../input/powerlifting-database/meets.csv")
powerlifting_competitors = pd.read_csv("../input/powerlifting-database/openpowerlifting.csv")'''
#left = powerlifting_meets.set_index('MeetID')
#right = powerlifting_competitors.set_index('MeetID')
#powerlifting_combined = left.join(right)
